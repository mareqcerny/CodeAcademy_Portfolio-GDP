# %% [markdown]
# # Life Expectancy and Gross Domestic Product

# %% [markdown]
# In this article we were looking at Life Expectancy and Gross Domestic Product for six different countries between the time span of 2000 and 2015. From developed countries we have : China, Germany and USA, folowing by less developed countries as Mexico, Chile and Zimbabwe.
#
# At first we will take a look individually on both topics and then we can try to find a relationship between Gross Domestic Product and Life Expectancy.

# %% [markdown]
# ## Gross Domestic Product (GDP)

# %% [markdown]
# ![gdp_all_countries.png](attachment:gdp_all_countries.png)

# %% [raw]
# Gross Domestic Product - or as we will call it from now on : GDP is the total price (in this case US dollars) of goods and services finished / or produced within a country. With our selection of countries, we will go as low as 4.4 billions of dollars in Zimbabwe and as high as 18 trillions of dollars in United States of America. Of course we can't compare these two countries economicaly, but it can help us to explore the relationship of GDP and Life Expectancy later on.

# %% [markdown]
# ## Life Expectancy

# %% [markdown]
# ![life_all_countries.png](attachment:life_all_countries.png)

# %% [markdown]
# As we can't compare economy of USA and Zimbabwe, we can't compare their Life expectancy either. These two companies are very different. Although in this case Zimbabwe is at the very bottom when it comes to life expectancy. The other 5 countries are pretty much similar and the difference is not as significant as we can see on the chart.

# %% [markdown]
# ## Relationship of GDP and Life expectancy

# %% [markdown]
# From both of our previous chart, we can see that the higher GDP is, the higher life expectancy goes. Which is a good sign and it means that if the economy of specific country is producing more money, the life expectancy is higher than before. Let's put both values on one chart to see if there really is a relationship between GDP and life expectancy.

# %% [markdown]
# ### Chart of GDP and Life expectancy in Zimbabwe

# %% [markdown]
# ![rel_zim.png](attachment:rel_zim.png)

# %% [markdown]
# ### Chart of GDP and Life expectancy in Germany

# %% [markdown]
# ![rel_ger_png.png](attachment:rel_ger_png.png)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# After putting both of those economic values on one chart, we can see that there is a significat relationship. Good economy is really connected and holding hand with life expectancy. And even though life expectancy in Zimbabwe is really low, we can't forget they their economy is really small compared to other countires. In conclusion we can confirm that it doesn't matter how big economy is, but as long as is moving forward and doing great, the life expectancy is improving as well.
